# %%
import numpy as np
import pandas as pd

# %%
a=0.3
b=0.05
sigma=0.03
t=5
r=0.08

# %%
B = (1-np.exp(-a*t))/(a)

# %%
print(B)
# Out:
# 2.5895661328385673

# %%
A = np.exp((((B-t)*((a*a*b)-(sigma*sigma)/2)))/(a*a)-((sigma*sigma*B*B)/(4*a)))

# %%
print(A)
# Out:
# 0.8927051662549038

# %%
ZCB = A*np.exp(-B*r)

# %%
print(ZCB)
# Out:
# 0.7256668859625068
